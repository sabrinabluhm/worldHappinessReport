# %% [markdown]
# ## World Happiness Report
#
# ### Merging the tables from the years 2005 - 2009

# %%
import pandas as pd
import numpy as np

table2015 = pd.read_csv('WorldHappinessScore_2015.csv', delimiter = ';')
table2015["year"] = 2015
#table2015.head(30)

table2016 = pd.read_csv('WorldHappinessScore_2016.csv', delimiter = ';')
table2016["year"] = 2016
#table2016.head(30)

table2017 = pd.read_csv('WorldHappinessScore_2017.csv', delimiter = ';')
table2017["year"] = 2017
#table2017.head(30)

table2018 = pd.read_csv('WorldHappinessScore_2018.csv', delimiter = ';')
table2018["year"] = 2018
#table2018.head(30)

table2019 = pd.read_csv('WorldHappinessScore_2019.csv', delimiter = ';')
table2019["year"] = 2019
#table2019.head(30)

tables = [table2015, table2016, table2017, table2018, table2019]

#mergedTables = pd.concat(tables, axis=0, join='outer', ignore_index=False, keys=None,
          #levels=None, names=None, verify_integrity=False, copy=True)
mergedTables = pd.concat(tables)

# %%
mergedTables.head(300)
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0    Switzerland               1            7.587                   1.39651
# 1        Iceland               2            7.561                   1.30232
# 2        Denmark               3            7.527                   1.32548
# 3         Norway               4            7.522                   1.45239
# 4         Canada               5            7.427                   1.32629
# ..           ...             ...              ...                       ...
# 137      Comoros             138            3.956                   0.27509
# 138  Ivory Coast             139            3.916                   0.55507
# 139     Cambodia             140            3.907                   0.55604
# 140       Angola             141            3.866                   0.84731
# 141        Niger             142            3.856                   0.13270
#
# ...

# %%
mergedTables.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 782 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        782 non-null    object
#  1   Happiness Rank                 782 non-null    int64
#  2   Happiness Score                782 non-null    float64
#  3   Economy (GDP per Capita)       782 non-null    float64
#  4   Family                         782 non-null    float64
#  5   Health (Life Expectancy)       782 non-null    float64
#  6   Freedom                        782 non-null    float64
#  7   Trust (Government Corruption)  781 non-null    float64
#  8   year                           782 non-null    int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 61.1+ KB

# %%
mergedTables.to_csv(r'/Users/sabrinarubert/Git/worldHappinessReport/mergedTable.csv', index=False)
